# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib notebook

# %%
df = pd.read_csv('Congregation_Data.csv',skiprows=4)
df1 = pd.read_csv('GDP_Data.csv')

# %%
#Religious Census Data State Wise for 2010
df.head()
# Out:
#         State  Population  PopRank  Adherents  AdhRank  Congregations  \
# 0     Alabama     4779736       23    3007553       16          10514
# 1      Alaska      710231       47     240833       49           1246
# 2     Arizona     6392017       16    2379928       23           4673
# 3    Arkansas     2915918       32    1614357       32           6697
# 4  California    37253956        1   16765751        1          23558
#
#    ConRank  Adherents %  Adh% Rank  Congregations Per 10K People  \
# 0       11         62.9          3                            22
# 1       45         33.9         48                            18
# 2       30         37.2         43                             7
# 3       20         55.4         13                            23
# 4        2         45.0         31                             6
#
#    Con Per 10K Rank
# 0                 6
# 1                12
# 2                44
# 3                 2
# 4                50

# %%
# GDP Data is Provided Year Wise, State Wise and Industry Wise in Million Dollars
df1.head()
# Out:
#   ComponentId                                      ComponentName  FIPS  \
# 0         200  Gross Domestic Product by State (millions of c...   0.0
# 1         200  Gross Domestic Product by State (millions of c...   0.0
# 2         200  Gross Domestic Product by State (millions of c...   0.0
# 3         200  Gross Domestic Product by State (millions of c...   0.0
# 4         200  Gross Domestic Product by State (millions of c...   0.0
#
#    Region        GeoName  IndustryId  \
# 0     0.0  United States       101.0
# 1     0.0  United States       102.0
# 2     0.0  United States       103.0
# 3     0.0  United States       104.0
# 4     0.0  United States       105.0
#
#                                      IndustryName     1997     1998     1999  \
# 0                              All industry total  8270462  8727023  9286858
# 1                              Private industries  7271021  7694421  8199565
# 2     Agriculture, forestry, fishing, and hunting   108368   100315    92829
# 3              Crop and animal production (Farms)    87949    79217    71189
# 4       Forestry, fishing, and related activities    20419    21099    21640
#
#    ...      2002      2003      2004      2005      2006      2007      2008  \
# 0  ...  10572388  11067829  11774410  12539116  13289235  13936199  14193120
# 1  ...   9289346   9706891  10345570  11037056  11709404  12268773  12437147
# 2  ...     94405    115539    142712    127101    122468    144542    159375
# 3  ...     72304     92412    118254    102018     93050    114893    130451
# 4  ...     22101     23127     24458     25084     29418     29649     28923
#
#        2009      2010      2011
# 0  13834700  14416601  14981020
# 1  12018095  12558037  13097365
# 2    139972    156984    177795
# 3    113128    132610      (NA)
# 4     26844     24374      (NA)
#
# [5 rows x 22 columns]

# %%
# 158 is the industry code for "Professional, Scientific and Technical Services"

df1.drop(df1[df1['IndustryId'] != 158].index, inplace = True)
df.set_index('State',inplace=True)
df1.set_index('GeoName',inplace=True)
data = df[['Population','Congregations']].join(df1['2010'])
data.columns =['Population','Congregations','Tech_GDP']

# %%
data = data.astype(float)
data.dtypes
# Out:
# Population       float64
# Congregations    float64
# Tech_GDP         float64
# dtype: object

# %%
data['Cong/Pop'] = data['Congregations']/data['Population']*1000000.0
data['GDP/Pop'] = data['Tech_GDP']/data['Population']*1000000.0
data.head()
# Out:
#             Population  Congregations  Tech_GDP     Cong/Pop      GDP/Pop
# State
# Alabama      4779736.0        10514.0   11113.0  2199.703080  2325.023809
# Alaska        710231.0         1246.0    2058.0  1754.358793  2897.648793
# Arizona      6392017.0         4673.0   15153.0   731.068143  2370.613220
# Arkansas     2915918.0         6697.0    4032.0  2296.703817  1382.754933
# California  37253956.0        23558.0  171267.0   632.362372  4597.283574

# %%
# Removing Outliers that our more than 3 Standard Deviations away from the Mean

mean = data['Cong/Pop'].mean()
sd = data['Cong/Pop'].std()
data.drop(data[((data['Cong/Pop'] - mean)/sd > 3) | ((data['Cong/Pop'] - mean)/sd < -3)].index, inplace = True)

mean = data['GDP/Pop'].mean()
sd = data['GDP/Pop'].std()
data.drop(data[((data['GDP/Pop'] - mean)/sd > 3) | ((data['GDP/Pop'] - mean)/sd < -3)].index, inplace = True)
data.shape
# Out:
# (50, 5)

# %%
sns.set(style="white", color_codes=True)
ax = sns.jointplot(data['Cong/Pop'],data['GDP/Pop'], kind='reg')
ax.set_axis_labels("(Religious Congregations per Million Population)", "(GDP per Capita in $ from Science-Tech Industry)")
ax.fig.suptitle("Regression Plot: Religiosity vs Tech-GDP (US States in 2010)")
ax.fig.tight_layout()
ax.fig.subplots_adjust(top=0.93);
# Out:
# <img src="data:image/png;base64,..." width="599.999976158143">
